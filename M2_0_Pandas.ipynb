# %%
# %matplotlib inline

# %% [markdown]
# <img src="img/intro/pandas_logo.png">
#
#
# **Pandas** es la librería por excelencia para el análisis de datos. Su nombre proviene de “panel data” (término econométrico). Inspirada en las funcionalidades de R, pero con el potencial de Python.
#
# **Pandas** incluye todas las funcionalidades para el análisis de datos: carga, filtrado, tratamiento, sintetización, agrupamiento, almacenamiento y visualización. Además se integra con el resto de librerías de calculo númerico como Numpy, Matplotlib, scikit-learn, …  y de despliegue: HPC, Cloud, etc.
#
#
#
# En resumen, **es como una hoja de calculo -por ejemplo excel- pero con más potencial!!!**
#
# [Main Features](https://github.com/pandas-dev/pandas#main-features)

# %% [markdown]
# ## Contenido
#
# - **M2_0 Introducción a la estructura DataFrame: características, carga y acceso.**
# - M2_1 Creación y Almacenamiento.
# - M2_2 Visualización con pandas.
# - M2_3 Otras operaciones con DataFrames: agrupaciones de datos.
# - M2_4 Gestionando datos perdidos.

# %% [markdown]
# ## Introducción a Pandas
#
# La estructura por excelencia es el DataFrame.
#
# Un **dataframe** es un objeto de dos dimensiones que contiene información. También puede verse como una **hoja de cálculo**, como una tabla de un modelo entidad-relación, o como una colección de una base de datos no relacional.
#
# [Documentación](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html)

# %% [markdown]
# Importación de la libreria
# ```Python
# import pandas as pd
# import pandas
# from pandas import *
# ```
#
# Por convención se hace de la siguiente manera, todas las funciones de la libreria se tienen que llamar con el prefijo pd.*:

# %%
import pandas as pd

# %% [markdown]
# # Primeros pasos con Pandas
# Vamos a aprender Pandas a través de una serie de proyectos y ejemplos.
#
# En este primera fase vamos a cargar datos de un fichero CSV, son ficheros donde los atributos/valores de una observación están separados por una coma y las observaciones se separan mediante un salto de línea.
#
# ### Ejemplo de un fichero CSV
# Nombre,Apellidos,Altura,Sexo,Nacimiento,Cof,Categoria<br/>
# Will,Smith,1.43,"M",10/10/1920,0.19,laboral<br/>
# Jon,Snow,1.98,"M",10/1/1970,0.98,laboral<br/>
# Laia,Ramirez,1.87,"F",09/10/1987,0.76,cap6<br/>
# Luzy,Raim,1.67,"F",23/07/1979,0.56,cap6<br/>
# Fein,Mang,1.78,"M",12/03/1937,0.27,cap6<br/>
# Victor,Colom,1.78,"M",22/09/1957,0.97,cap8<br/>
#
#
# **Datos:**
# http://www.exploredata.net/Downloads/WHO-Data-Set

# %% [markdown]
# Empezamos viendo como se carga un dataframe a partir de un fichero en formato CSV.

# %%
df = pd.read_csv("WHO.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-31f5dfb5c5fc> in <module>
# ----> 1 df = pd.read_csv("WHO.csv")
#
# NameError: name 'pd' is not defined

# %% [markdown]
# A continuación se muestra la estructura interna del DataFrame. Se puede ver que és muy parecido a una tabla bidimensional, además permite toda la funcionalidad de las hojas de cáclulo, y muchísimas más. Durante el transcurso del curso veremos las más importantes.

# %%
df
# Out:
#                       Country  CountryID  Continent  \
# 0                 Afghanistan          1          1
# 1                     Albania          2          2
# 2                     Algeria          3          3
# 3                     Andorra          4          2
# 4                      Angola          5          3
# 5         Antigua and Barbuda          6          4
# 6                   Argentina          7          5
# 7                     Armenia          8          2
# 8                   Australia          9          6
# 9                     Austria         10          2
# 10                 Azerbaijan         11          2
# 11                    Bahamas         12          4
# 12                    Bahrain         13          1
# 13                 Bangladesh         14          7
# 14                   Barbados         15          4
# 15                    Belarus         16          2
# 16                    Belgium         17          2
# 17                     Belize         18          5
# 18                      Benin         19          3
# 19                    Bermuda         20          4
# 20                     Bhutan         21          7
# 21                    Bolivia         22          5
# 22     Bosnia and Herzegovina         23          2
# 23                   Botswana         24          3
# 24                     Brazil         25          5
# 25          Brunei Darussalam         26          6
# 26                   Bulgaria         27          2
# 27               Burkina Faso         28          3
# 28                    Burundi         29          3
# 29                   Cambodia         30          7
# ..                        ...        ...        ...
# 172                 Swaziland        173          3
# 173                    Sweden        174          2
# 174               Switzerland        175          2
# 175                     Syria        176          1
# 176                    Taiwan        177          6
# 177                Tajikistan        178          2
# 178                  Tanzania        179          3
# 179                  Thailand        180          6
# 180               Timor-Leste        181          6
# 181                      Togo        182          3
# 182                     Tonga        183          6
# 183       Trinidad and Tobago        184          5
# 184                   Tunisia        185          1
# 185                    Turkey        186          2
# 186              Turkmenistan        187          2
# 187                    Tuvalu        188          6
# 188                    Uganda        189          3
# 189                   Ukraine        190          2
# 190      United Arab Emirates        191          1
# 191            United Kingdom        192          2
# 192  United States of America        193          4
# 193                   Uruguay        194          5
# 194                Uzbekistan        195          2
# 195                   Vanuatu        196          6
# 196                 Venezuela        197          5
# 197                   Vietnam        198          6
# 198        West Bank and Gaza        199          1
# 199                     Yemen        200          1
# 200                    Zambia        201          3
# 201                  Zimbabwe        202          3
#
#      Adolescent fertility rate (%)  Adult literacy rate (%)  \
# 0                            151.0                     28.0
# 1                             27.0                     98.7
# 2                              6.0                     69.9
# 3                              NaN                      NaN
# 4                            146.0                     67.4
# 5                              NaN                      NaN
# 6                             62.0                     97.2
# 7                             30.0                     99.4
# 8                             16.0                      NaN
# 9                             14.0                      NaN
# 10                            31.0                     98.8
# 11                            46.0                      NaN
# 12                            14.0                     86.5
# 13                           135.0                     47.5
# 14                            51.0                      NaN
# 15                            22.0                     99.6
# 16                             5.0                      NaN
# 17                            90.0                     70.3
# 18                           108.0                     34.7
# 19                             NaN                      NaN
# 20                            62.0                      NaN
# 21                            97.0                     86.7
# 22                            25.0                     96.7
# 23                            51.0                     81.2
# 24                            71.0                     88.6
# 25                            31.0                     92.7
# 26                            40.0                     98.2
# 27                           131.0                     23.6
# 28                            30.0                     59.3
# 29                            52.0                     73.6
# ..                             ...                      ...
# 172                           73.0                     79.6
# 173                            7.0                      NaN
# 174                            5.0                      NaN
# 175                           58.0                     80.8
# 176                            NaN                      NaN
# 177                           57.0                     99.5
# 178                          139.0                     69.4
# 179                           70.0                     92.6
# 180                           49.0                      NaN
# 181                           89.0                     53.2
# 182                           17.0                     98.9
# 183                           35.0                     98.5
# 184                            8.0                     74.3
# 185                           51.0                     87.4
# 186                           29.0                     98.8
# 187                            NaN                      NaN
# 188                          159.0                     68.1
# 189                           29.0                     99.4
# 190                           37.0                     88.5
# 191                           27.0                      NaN
# 192                           43.0                      NaN
# 193                           64.0                     96.8
# 194                           40.0                      NaN
# 195                           92.0                     75.5
# 196                           81.0                     93.0
# 197                           25.0                     90.3
# 198                            NaN                      NaN
# 199                           83.0                     54.1
# 200                          161.0                     68.0
# 201                          101.0                     89.5
#
#      Gross national income per capita (PPP international $)  \
# 0                                                  NaN
# 1                                               6000.0
# 2                                               5940.0
# 3                                                  NaN
# 4                                               3890.0
# 5                                              15130.0
# 6                                              11670.0
# 7                                               4950.0
# 8                                              33940.0
# 9                                              36040.0
# 10                                              5430.0
# 11                                                 NaN
# 12                                             34310.0
# 13                                              1230.0
# 14                                             15150.0
# 15                                              9700.0
# 16                                             33860.0
# 17                                              7080.0
# 18                                              1250.0
# 19                                                 NaN
# 20                                              4000.0
# 21                                              3810.0
# 22                                              6780.0
# 23                                             11730.0
# 24                                              8700.0
# 25                                             49900.0
# 26                                             10270.0
# 27                                              1130.0
# 28                                               320.0
# 29                                              1550.0
# ..                                                 ...
# 172                                             4700.0
# 173                                            34310.0
# 174                                            40840.0
# 175                                             4110.0
# 176                                                NaN
# 177                                             1560.0
# 178                                              980.0
# 179                                             7440.0
# 180                                             5100.0
# 181                                              770.0
# 182                                             5470.0
# 183                                            16800.0
# 184                                             6490.0
# 185                                             8410.0
# 186                                             3990.0
# 187                                                NaN
# 188                                              880.0
# 189                                             6110.0
# 190                                            31190.0
# 191                                            33650.0
# 192                                            44070.0
# 193                                             9940.0
# 194                                             2190.0
# 195                                             3480.0
# 196                                            10970.0
# 197                                             2310.0
# 198                                                NaN
# 199                                             2090.0
# 200                                             1140.0
# 201                                                NaN
#
#      Net primary school enrolment ratio female (%)  \
# 0                                              NaN
# 1                                             93.0
# 2                                             94.0
# 3                                             83.0
# 4                                             49.0
# 5                                              NaN
# 6                                             98.0
# 7                                             84.0
# 8                                             97.0
# 9                                             98.0
# 10                                            83.0
# 11                                            89.0
# 12                                            98.0
# 13                                            90.0
# 14                                            96.0
# 15                                            88.0
# 16                                            97.0
# 17                                            97.0
# 18                                            73.0
# 19                                             NaN
# 20                                            79.0
# 21                                            95.0
# 22                                             NaN
# 23                                            85.0
# 24                                            95.0
# 25                                            94.0
# 26                                            92.0
# 27                                            42.0
# 28                                            73.0
# 29                                            89.0
# ..                                             ...
# 172                                           79.0
# 173                                           95.0
# 174                                           89.0
# 175                                           92.0
# 176                                            NaN
# 177                                           95.0
# 178                                           97.0
# 179                                           94.0
# 180                                           67.0
# 181                                           75.0
# 182                                           94.0
# 183                                           85.0
# 184                                           97.0
# 185                                           89.0
# 186                                            NaN
# 187                                            NaN
# 188                                            NaN
# 189                                           90.0
# 190                                           88.0
# 191                                           99.0
# 192                                           93.0
# 193                                          100.0
# 194                                           78.0
# 195                                           86.0
# 196                                           91.0
# 197                                           91.0
# 198                                            NaN
# 199                                           65.0
# 200                                           94.0
# 201                                           88.0
#
#      Net primary school enrolment ratio male (%)  \
# 0                                            NaN
# 1                                           94.0
# 2                                           96.0
# 3                                           83.0
# 4                                           51.0
# 5                                            NaN
# 6                                           99.0
# 7                                           80.0
# 8                                           96.0
# 9                                           97.0
# 10                                          86.0
# 11                                          87.0
# 12                                          98.0
# 13                                          87.0
# 14                                          97.0
# 15                                          90.0
# 16                                          97.0
# 17                                          97.0
# 18                                          87.0
# 19                                           NaN
# 20                                          79.0
# 21                                          94.0
# 22                                           NaN
# 23                                          83.0
# 24                                          93.0
# 25                                          94.0
# 26                                          93.0
# 27                                          52.0
# 28                                          76.0
# 29                                          91.0
# ..                                           ...
# 172                                         78.0
# 173                                         95.0
# 174                                         89.0
# 175                                         97.0
# 176                                          NaN
# 177                                         99.0
# 178                                         98.0
# 179                                         94.0
# 180                                         70.0
# 181                                         86.0
# 182                                         97.0
# 183                                         85.0
# 184                                         96.0
# 185                                         93.0
# 186                                          NaN
# 187                                          NaN
# 188                                          NaN
# 189                                         90.0
# 190                                         88.0
# 191                                         98.0
# 192                                         91.0
# 193                                        100.0
# 194                                         79.0
# 195                                         88.0
# 196                                         91.0
# 197                                         96.0
# 198                                          NaN
# 199                                         85.0
# 200                                         90.0
# 201                                         87.0
#
#      Population (in thousands) total  Population annual growth rate (%)  ...  \
# 0                            26088.0                                4.0  ...
# 1                             3172.0                                0.6  ...
# 2                            33351.0                                1.5  ...
# 3                               74.0                                1.0  ...
# 4                            16557.0                                2.8  ...
# 5                               84.0                                1.3  ...
# 6                            39134.0                                1.0  ...
# 7                             3010.0                               -0.3  ...
# 8                            20530.0                                1.1  ...
# 9                             8327.0                                0.4  ...
# 10                            8406.0                                0.6  ...
# 11                             327.0                                1.2  ...
# 12                             739.0                                1.9  ...
# 13                          155991.0                                1.8  ...
# 14                             293.0                                0.3  ...
# 15                            9742.0                               -0.5  ...
# 16                           10430.0                                0.3  ...
# 17                             282.0                                2.2  ...
# 18                            8760.0                                3.1  ...
# 19                               NaN                                NaN  ...
# 20                             649.0                                1.8  ...
# 21                            9354.0                                1.9  ...
# 22                            3926.0                                0.3  ...
# 23                            1858.0                                1.2  ...
# 24                          189323.0                                1.3  ...
# 25                             382.0                                2.1  ...
# 26                            7693.0                               -0.7  ...
# 27                           14359.0                                3.0  ...
# 28                            8173.0                                3.9  ...
# 29                           14197.0                                1.7  ...
# ..                               ...                                ...  ...
# 172                           1134.0                                0.8  ...
# 173                           9078.0                                0.4  ...
# 174                           7455.0                                0.4  ...
# 175                          19408.0                                2.7  ...
# 176                              NaN                                NaN  ...
# 177                           6640.0                                1.4  ...
# 178                          39459.0                                2.5  ...
# 179                          63444.0                                0.7  ...
# 180                           1114.0                                4.3  ...
# 181                           6410.0                                2.7  ...
# 182                            100.0                                0.5  ...
# 183                           1328.0                                0.4  ...
# 184                          10215.0                                1.1  ...
# 185                          73922.0                                1.3  ...
# 186                           4899.0                                1.4  ...
# 187                             10.0                                0.4  ...
# 188                          29899.0                                3.2  ...
# 189                          46557.0                               -0.8  ...
# 190                           4248.0                                3.5  ...
# 191                          60512.0                                0.4  ...
# 192                         302841.0                                1.0  ...
# 193                           3331.0                                0.2  ...
# 194                          26981.0                                1.4  ...
# 195                            221.0                                2.5  ...
# 196                          27191.0                                1.7  ...
# 197                          86206.0                                1.4  ...
# 198                              NaN                                NaN  ...
# 199                          21732.0                                3.0  ...
# 200                          11696.0                                1.9  ...
# 201                          13228.0                                0.8  ...
#
#      Total_CO2_emissions  Total_income  Total_reserves  \
# 0                 692.50           NaN             NaN
# 1                3499.12  4.790000e+09           78.14
# 2              137535.56  6.970000e+10          351.36
# 3                    NaN           NaN             NaN
# 4                8991.46  1.490000e+10           27.13
# 5                 421.36  8.300000e+08             NaN
# 6              152711.86  3.140000e+11           21.11
# 7                4345.50  3.400000e+09           35.98
# 8              368858.53  4.680000e+11             NaN
# 9               73602.43  2.090000e+11             NaN
# 10              36629.01  9.930000e+09           64.89
# 11               2106.80  4.940000e+09             NaN
# 12              19668.35  1.060000e+10             NaN
# 13              39952.26  6.140000e+10           14.92
# 14               1315.38           NaN             NaN
# 15              63299.27  1.830000e+10           28.31
# 16             102599.33  2.490000e+11             NaN
# 17                817.07  1.080000e+09            7.11
# 18               2564.80  2.730000e+09           35.41
# 19                571.58           NaN             NaN
# 20                414.03  6.440000e+08           72.00
# 21               9251.60  9.740000e+09           25.88
# 22              26274.55  6.440000e+09           47.80
# 23               4554.35  8.050000e+09         1334.86
# 24             325487.78  7.380000e+11           28.72
# 25               5891.71  4.830000e+09             NaN
# 26              44422.34  1.640000e+10           55.40
# 27                743.79  3.430000e+09           21.47
# 28                223.50  7.900000e+08            7.61
# 29                538.61  5.680000e+09           32.94
# ..                   ...           ...             ...
# 172               956.30  1.560000e+09           45.95
# 173             48511.36  2.700000e+11             NaN
# 174             41165.04  2.590000e+11             NaN
# 175             68428.87  2.360000e+10             NaN
# 176            245806.77           NaN             NaN
# 177              5235.86  1.530000e+09           18.28
# 178              4671.60  1.250000e+10           26.28
# 179            270894.20  1.570000e+11          100.87
# 180                  NaN           NaN             NaN
# 181              1344.69  1.480000e+09           11.39
# 182               117.25  1.670000e+08           57.30
# 183             32657.23  1.190000e+10             NaN
# 184             21976.67  2.420000e+10           25.75
# 185            247873.27  2.460000e+11           31.01
# 186             41634.03  2.900000e+09           57.39
# 187                  NaN           NaN             NaN
# 188              2308.32  7.790000e+09           30.36
# 189            327129.25  4.520000e+10           58.23
# 190            123733.28  1.040000e+11             NaN
# 191            546416.00  1.620000e+12             NaN
# 192           5776431.50  1.100000e+13             NaN
# 193              5558.29  2.160000e+10           21.15
# 194            112356.56  1.790000e+10           25.15
# 195                87.94  2.560000e+08           81.85
# 196            148117.20  1.330000e+11           65.19
# 197            101826.23  4.480000e+10           47.11
# 198               655.86  3.780000e+09             NaN
# 199             20148.34  1.150000e+10          114.52
# 200              2366.94  4.090000e+09           10.41
# 201             11457.33  5.620000e+09            3.39
#
#      Trade_balance_goods_and_services  Under_five_mortality_from_CME  \
# 0                                 NaN                         257.00
# 1                       -2.040000e+09                          18.47
# 2                        4.700000e+09                          40.00
# 3                                 NaN                            NaN
# 4                        9.140000e+09                         164.10
# 5                       -1.020000e+08                          12.60
# 6                        1.190000e+10                          18.10
# 7                       -6.470000e+08                          28.80
# 8                       -1.280000e+10                           5.90
# 9                        8.240000e+09                           5.10
# 10                       1.330000e+09                          50.00
# 11                      -7.410000e+08                          15.80
# 12                       3.210000e+09                          10.96
# 13                      -4.160000e+09                          72.00
# 14                      -3.080000e+08                          12.20
# 15                       2.090000e+08                          15.10
# 16                       1.070000e+10                           5.00
# 17                      -9.910000e+07                          26.70
# 18                      -3.730000e+08                         132.00
# 19                                NaN                            NaN
# 20                                NaN                          92.80
# 21                       4.630000e+08                          68.80
# 22                      -4.460000e+09                          15.40
# 23                       1.600000e+09                          47.30
# 24                       3.660000e+10                          25.60
# 25                                NaN                           8.80
# 26                      -4.450000e+09                          14.30
# 27                      -3.900000e+08                         190.36
# 28                      -2.320000e+08                         181.30
# 29                      -5.470000e+08                          97.30
# ..                                ...                            ...
# 172                     -1.020000e+08                         110.30
# 173                      2.700000e+10                           3.90
# 174                      2.570000e+10                           5.30
# 175                     -9.490000e+08                          19.00
# 176                               NaN                            NaN
# 177                     -4.280000e+08                          77.70
# 178                     -1.260000e+09                         128.40
# 179                     -3.750000e+09                           9.00
# 180                               NaN                            NaN
# 181                     -6.140000e+08                         109.00
# 182                     -9.460000e+07                          24.48
# 183                      1.990000e+09                          35.10
# 184                     -1.460000e+08                          25.40
# 185                     -1.830000e+10                          32.60
# 186                     -6.340000e+08                          58.10
# 187                               NaN                            NaN
# 188                     -1.210000e+09                         138.20
# 189                      6.710000e+08                          23.80
# 190                               NaN                           8.80
# 191                     -8.020000e+10                           6.10
# 192                     -7.140000e+11                           8.00
# 193                      3.930000e+08                          15.18
# 194                               NaN                          48.90
# 195                     -3.740000e+07                          39.94
# 196                      2.790000e+10                          21.10
# 197                     -1.940000e+09                          20.20
# 198                               NaN                          28.00
# 199                      8.310000e+08                          82.40
# 200                     -4.470000e+08                         175.30
# 201                     -1.710000e+08                         106.50
#
#      Under_five_mortality_from_IHME  Under_five_mortality_rate  \
# 0                             231.9                     257.00
# 1                              15.5                      18.47
# 2                              31.2                      40.00
# 3                               NaN                        NaN
# 4                             242.5                     164.10
# 5                               NaN                      12.60
# 6                              16.7                      18.10
# 7                              27.7                      28.80
# 8                               5.1                       5.90
# 9                               4.3                       5.10
# 10                             63.7                      50.00
# 11                             10.2                      15.80
# 12                              7.0                      10.96
# 13                             76.0                      72.00
# 14                             10.8                      12.20
# 15                             10.3                      15.10
# 16                              4.8                       5.00
# 17                             15.7                      26.70
# 18                            133.6                     132.00
# 19                              NaN                        NaN
# 20                             65.8                      92.80
# 21                             67.3                      68.80
# 22                              8.4                      15.40
# 23                             39.8                      47.30
# 24                             25.5                      25.60
# 25                              7.2                       8.80
# 26                             15.2                      14.30
# 27                            168.2                     190.36
# 28                            190.3                     181.30
# 29                             94.3                      97.30
# ..                              ...                        ...
# 172                            80.8                     110.30
# 173                             3.5                       3.90
# 174                             4.7                       5.30
# 175                            23.6                      19.00
# 176                             NaN                        NaN
# 177                            60.4                      77.70
# 178                           121.3                     128.40
# 179                            13.7                       9.00
# 180                             NaN                        NaN
# 181                           109.7                     109.00
# 182                             NaN                      24.48
# 183                            20.2                      35.10
# 184                            23.0                      25.40
# 185                            34.1                      32.60
# 186                            65.7                      58.10
# 187                             NaN                        NaN
# 188                           135.9                     138.20
# 189                            13.3                      23.80
# 190                             5.6                       8.80
# 191                             5.4                       6.10
# 192                             7.1                       8.00
# 193                            13.6                      15.18
# 194                            34.3                      48.90
# 195                            43.0                      39.94
# 196                            18.1                      21.10
# 197                            23.4                      20.20
# 198                            25.8                      28.00
# 199                            87.9                      82.40
# 200                           163.8                     175.30
# 201                            67.0                     106.50
#
#      Urban_population  Urban_population_growth  Urban_population_pct_of_total
# 0        5.740436e+06                     5.44                           22.9
# 1        1.431794e+06                     2.21                           45.4
# 2        2.080000e+07                     2.61                           63.3
# 3                 NaN                      NaN                            NaN
# 4        8.578749e+06                     4.14                           53.3
# 5        3.246825e+04                     2.25                           39.1
# 6        3.490000e+07                     1.17                           90.1
# 7        1.934321e+06                    -0.62                           64.1
# 8        1.800000e+07                     1.54                           88.2
# 9        5.433978e+06                     0.77                           66.0
# 10       4.321803e+06                     1.26                           51.5
# 11       2.922587e+05                     1.59                           90.4
# 12       6.994204e+05                     2.43                           96.5
# 13       3.850000e+07                     3.34                           25.1
# 14       1.538487e+05                     1.42                           52.7
# 15       7.057977e+06                     0.11                           72.2
# 16       1.020000e+07                     0.57                           97.2
# 17       1.409394e+05                     3.45                           48.3
# 18       3.404611e+06                     4.04                           40.1
# 19       6.357000e+04                     0.39                          100.0
# 20       7.070845e+04                     4.95                           11.1
# 21       5.894854e+06                     2.65                           64.2
# 22       1.789264e+06                     1.35                           45.7
# 23       1.053828e+06                     2.62                           57.4
# 24       1.570000e+08                     2.07                           84.2
# 25       2.747658e+05                     2.86                           73.5
# 26       5.418000e+06                    -0.21                           70.0
# 27       2.549806e+06                     5.09                           18.3
# 28       7.858791e+05                     6.64                           10.0
# 29       2.749235e+06                     4.58                           19.7
# ..                ...                      ...                            ...
# 172      2.725710e+05                     1.66                           24.1
# 173      7.598242e+06                     0.40                           84.2
# 174      5.592699e+06                     1.20                           75.2
# 175      9.560304e+06                     2.91                           50.6
# 176               NaN                      NaN                            NaN
# 177      1.617903e+06                     0.31                           24.7
# 178      9.311645e+06                     4.14                           24.2
# 179      2.030000e+07                     1.44                           32.3
# 180               NaN                      NaN                            NaN
# 181      2.501667e+06                     4.49                           40.1
# 182      2.384664e+04                     1.04                           24.0
# 183      1.614941e+05                     2.67                           12.2
# 184      6.548937e+06                     1.55                           65.3
# 185      4.850000e+07                     2.05                           67.3
# 186      2.232969e+06                     1.88                           46.2
# 187               NaN                      NaN                            NaN
# 188      3.647345e+06                     4.03                           12.6
# 189      3.190000e+07                    -0.53                           67.8
# 190      3.147991e+06                     3.72                           76.7
# 191      5.400000e+07                     0.72                           89.7
# 192      2.400000e+08                     1.39                           80.8
# 193      3.041265e+06                     0.27                           92.0
# 194      9.603424e+06                     0.84                           36.7
# 195      5.061101e+04                     4.11                           23.5
# 196      2.480000e+07                     2.20                           93.4
# 197      2.190000e+07                     2.90                           26.4
# 198      2.596216e+06                     3.33                           71.6
# 199      5.759120e+06                     4.37                           27.3
# 200      4.017411e+06                     1.95                           35.0
# 201      4.709965e+06                     1.90                           35.9
#
# [202 rows x 358 columns]

# %% [markdown]
# ### Atributos de un DataFrame
#
# Un dataframe dispone de diferentes atributos con los que se puede consultar su información o metainformación.
#
# Los siguientes ejemplos muestran cómo se pueden consultar sus dimensiones o un listado del nombre de sus columnas.

# %%
df.shape # Ver las dimensiones **
# Out:
# (202, 358)

# %%
df.columns #**
# Out:
# Index([u'Country', u'CountryID', u'Continent',
#        u'Adolescent fertility rate (%)', u'Adult literacy rate (%)',
#        u'Gross national income per capita (PPP international $)',
#        u'Net primary school enrolment ratio female (%)',
#        u'Net primary school enrolment ratio male (%)',
#        u'Population (in thousands) total',
#        u'Population annual growth rate (%)',
#        ...
#        u'Total_CO2_emissions', u'Total_income', u'Total_reserves',
#        u'Trade_balance_goods_and_services', u'Under_five_mortality_from_CME',
#        u'Under_five_mortality_from_IHME', u'Under_five_mortality_rate',
#        u'Urban_population', u'Urban_population_growth',
#        u'Urban_population_pct_of_total'],
#       dtype='object', length=358)

# %% [markdown]
# Podemos aplicar sobre el listado de columnas todas las operaciones sobre listas que hemos visto en la introducción del curso.
# A continuación tenemos dos ejemplos de indexación

# %%
df.columns[0]
# Out:
# 'Country'

# %%
df.columns[:2]
# Out:
# Index([u'Country', u'CountryID'], dtype='object')

# %% [markdown]
# **¿Cómo consultariais el nombre de la columna 10? ¿y los de las columnas de la 200 a la 225?**

# %% [markdown]
# ## Funciones descriptivas de un dataframe

# %%
df.describe()
# Out:
#         CountryID   Continent  Adolescent fertility rate (%)  \
# count  202.000000  202.000000                     177.000000
# mean   101.500000    3.579208                      59.457627
# std     58.456537    1.808263                      49.105286
# min      1.000000    1.000000                       0.000000
# 25%     51.250000    2.000000                      19.000000
# 50%    101.500000    3.000000                      46.000000
# 75%    151.750000    5.000000                      91.000000
# max    202.000000    7.000000                     199.000000
#
#        Adult literacy rate (%)  \
# count               131.000000
# mean                 78.871756
# std                  20.415760
# min                  23.600000
# 25%                  68.400000
# 50%                  86.500000
# 75%                  95.300000
# max                  99.800000
#
#        Gross national income per capita (PPP international $)  \
# count                                         178.000000
# mean                                        11250.112360
# std                                         12586.753417
# min                                           260.000000
# 25%                                          2112.500000
# 50%                                          6175.000000
# 75%                                         14502.500000
# max                                         60870.000000
#
#        Net primary school enrolment ratio female (%)  \
# count                                     179.000000
# mean                                       84.033520
# std                                        17.788047
# min                                         6.000000
# 25%                                        79.000000
# 50%                                        90.000000
# 75%                                        96.000000
# max                                       100.000000
#
#        Net primary school enrolment ratio male (%)  \
# count                                   179.000000
# mean                                     85.698324
# std                                      15.451212
# min                                      11.000000
# 25%                                      79.500000
# 50%                                      90.000000
# 75%                                      96.000000
# max                                     100.000000
#
#        Population (in thousands) total  Population annual growth rate (%)  \
# count                     1.930000e+02                         193.000000
# mean                      3.409805e+04                           1.297927
# std                       1.304957e+05                           1.163864
# min                       2.000000e+00                          -2.500000
# 25%                       1.340000e+03                           0.500000
# 50%                       6.762000e+03                           1.300000
# 75%                       2.173200e+04                           2.100000
# max                       1.328474e+06                           4.300000
#
#        Population in urban areas (%)  ...  Total_CO2_emissions  Total_income  \
# count                     193.000000  ...         1.860000e+02  1.780000e+02
# mean                       54.911917  ...         1.483596e+05  2.015567e+11
# std                        23.554182  ...         6.133091e+05  9.400689e+11
# min                        10.000000  ...         2.565000e+01  5.190000e+07
# 25%                        36.000000  ...         1.672615e+03  3.317500e+09
# 50%                        57.000000  ...         1.021157e+04  1.145000e+10
# 75%                        73.000000  ...         6.549217e+04  8.680000e+10
# max                       100.000000  ...         5.776432e+06  1.100000e+13
#
#        Total_reserves  Trade_balance_goods_and_services  \
# count      128.000000                      1.710000e+02
# mean        57.253516                      3.424012e+08
# std        138.669298                      5.943043e+10
# min          0.990000                     -7.140000e+11
# 25%         16.292500                     -1.210000e+09
# 50%         28.515000                     -2.240000e+08
# 75%         55.310000                      1.024000e+09
# max       1334.860000                      1.390000e+11
#
#        Under_five_mortality_from_CME  Under_five_mortality_from_IHME  \
# count                     181.000000                      170.000000
# mean                       56.677624                       54.356471
# std                        60.060929                       61.160556
# min                         2.900000                        3.000000
# 25%                        12.400000                        8.475000
# 50%                        29.980000                       27.600000
# 75%                        88.700000                       82.900000
# max                       267.000000                      253.700000
#
#        Under_five_mortality_rate  Urban_population  Urban_population_growth  \
# count                 181.000000      1.880000e+02               188.000000
# mean                   56.677624      1.665763e+07                 2.165851
# std                    60.060929      5.094867e+07                 1.596628
# min                     2.900000      1.545600e+04                -1.160000
# 25%                    12.400000      9.171623e+05                 1.105000
# 50%                    29.980000      3.427661e+06                 1.945000
# 75%                    88.700000      9.837113e+06                 3.252500
# max                   267.000000      5.270000e+08                 7.850000
#
#        Urban_population_pct_of_total
# count                     188.000000
# mean                       55.195213
# std                        23.742122
# min                        10.000000
# 25%                        35.650000
# 50%                        57.300000
# 75%                        72.750000
# max                       100.000000
#
# [8 rows x 357 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Columns: 358 entries, Country to Urban_population_pct_of_total
# dtypes: float64(355), int64(2), object(1)
# memory usage: 565.0+ KB

# %%
df.head()
# Out:
#        Country  CountryID  Continent  Adolescent fertility rate (%)  \
# 0  Afghanistan          1          1                          151.0
# 1      Albania          2          2                           27.0
# 2      Algeria          3          3                            6.0
# 3      Andorra          4          2                            NaN
# 4       Angola          5          3                          146.0
#
#    Adult literacy rate (%)  \
# 0                     28.0
# 1                     98.7
# 2                     69.9
# 3                      NaN
# 4                     67.4
#
#    Gross national income per capita (PPP international $)  \
# 0                                                NaN
# 1                                             6000.0
# 2                                             5940.0
# 3                                                NaN
# 4                                             3890.0
#
#    Net primary school enrolment ratio female (%)  \
# 0                                            NaN
# 1                                           93.0
# 2                                           94.0
# 3                                           83.0
# 4                                           49.0
#
#    Net primary school enrolment ratio male (%)  \
# 0                                          NaN
# 1                                         94.0
# 2                                         96.0
# 3                                         83.0
# 4                                         51.0
#
#    Population (in thousands) total  Population annual growth rate (%)  ...  \
# 0                          26088.0                                4.0  ...
# 1                           3172.0                                0.6  ...
# 2                          33351.0                                1.5  ...
# 3                             74.0                                1.0  ...
# 4                          16557.0                                2.8  ...
#
#    Total_CO2_emissions  Total_income  Total_reserves  \
# 0               692.50           NaN             NaN
# 1              3499.12  4.790000e+09           78.14
# 2            137535.56  6.970000e+10          351.36
# 3                  NaN           NaN             NaN
# 4              8991.46  1.490000e+10           27.13
#
#    Trade_balance_goods_and_services  Under_five_mortality_from_CME  \
# 0                               NaN                         257.00
# 1                     -2.040000e+09                          18.47
# 2                      4.700000e+09                          40.00
# 3                               NaN                            NaN
# 4                      9.140000e+09                         164.10
#
#    Under_five_mortality_from_IHME  Under_five_mortality_rate  \
# 0                           231.9                     257.00
# 1                            15.5                      18.47
# 2                            31.2                      40.00
# 3                             NaN                        NaN
# 4                           242.5                     164.10
#
#    Urban_population  Urban_population_growth  Urban_population_pct_of_total
# 0         5740436.0                     5.44                           22.9
# 1         1431793.9                     2.21                           45.4
# 2        20800000.0                     2.61                           63.3
# 3               NaN                      NaN                            NaN
# 4         8578749.0                     4.14                           53.3
#
# [5 rows x 358 columns]

# %%
df.tail()
# Out:
#                 Country  CountryID  Continent  Adolescent fertility rate (%)  \
# 197             Vietnam        198          6                           25.0
# 198  West Bank and Gaza        199          1                            NaN
# 199               Yemen        200          1                           83.0
# 200              Zambia        201          3                          161.0
# 201            Zimbabwe        202          3                          101.0
#
#      Adult literacy rate (%)  \
# 197                     90.3
# 198                      NaN
# 199                     54.1
# 200                     68.0
# 201                     89.5
#
#      Gross national income per capita (PPP international $)  \
# 197                                             2310.0
# 198                                                NaN
# 199                                             2090.0
# 200                                             1140.0
# 201                                                NaN
#
#      Net primary school enrolment ratio female (%)  \
# 197                                           91.0
# 198                                            NaN
# 199                                           65.0
# 200                                           94.0
# 201                                           88.0
#
#      Net primary school enrolment ratio male (%)  \
# 197                                         96.0
# 198                                          NaN
# 199                                         85.0
# 200                                         90.0
# 201                                         87.0
#
#      Population (in thousands) total  Population annual growth rate (%)  ...  \
# 197                          86206.0                                1.4  ...
# 198                              NaN                                NaN  ...
# 199                          21732.0                                3.0  ...
# 200                          11696.0                                1.9  ...
# 201                          13228.0                                0.8  ...
#
#      Total_CO2_emissions  Total_income  Total_reserves  \
# 197            101826.23  4.480000e+10           47.11
# 198               655.86  3.780000e+09             NaN
# 199             20148.34  1.150000e+10          114.52
# 200              2366.94  4.090000e+09           10.41
# 201             11457.33  5.620000e+09            3.39
#
#      Trade_balance_goods_and_services  Under_five_mortality_from_CME  \
# 197                     -1.940000e+09                           20.2
# 198                               NaN                           28.0
# 199                      8.310000e+08                           82.4
# 200                     -4.470000e+08                          175.3
# 201                     -1.710000e+08                          106.5
#
#      Under_five_mortality_from_IHME  Under_five_mortality_rate  \
# 197                            23.4                       20.2
# 198                            25.8                       28.0
# 199                            87.9                       82.4
# 200                           163.8                      175.3
# 201                            67.0                      106.5
#
#      Urban_population  Urban_population_growth  Urban_population_pct_of_total
# 197        21900000.0                     2.90                           26.4
# 198         2596216.0                     3.33                           71.6
# 199         5759120.5                     4.37                           27.3
# 200         4017411.0                     1.95                           35.0
# 201         4709965.0                     1.90                           35.9
#
# [5 rows x 358 columns]

# %%
df.tail(2)
# Out:
#       Country  CountryID  Continent  Adolescent fertility rate (%)  \
# 200    Zambia        201          3                          161.0
# 201  Zimbabwe        202          3                          101.0
#
#      Adult literacy rate (%)  \
# 200                     68.0
# 201                     89.5
#
#      Gross national income per capita (PPP international $)  \
# 200                                             1140.0
# 201                                                NaN
#
#      Net primary school enrolment ratio female (%)  \
# 200                                           94.0
# 201                                           88.0
#
#      Net primary school enrolment ratio male (%)  \
# 200                                         90.0
# 201                                         87.0
#
#      Population (in thousands) total  Population annual growth rate (%)  ...  \
# 200                          11696.0                                1.9  ...
# 201                          13228.0                                0.8  ...
#
#      Total_CO2_emissions  Total_income  Total_reserves  \
# 200              2366.94  4.090000e+09           10.41
# 201             11457.33  5.620000e+09            3.39
#
#      Trade_balance_goods_and_services  Under_five_mortality_from_CME  \
# 200                      -447000000.0                          175.3
# 201                      -171000000.0                          106.5
#
#      Under_five_mortality_from_IHME  Under_five_mortality_rate  \
# 200                           163.8                      175.3
# 201                            67.0                      106.5
#
#      Urban_population  Urban_population_growth  Urban_population_pct_of_total
# 200         4017411.0                     1.95                           35.0
# 201         4709965.0                     1.90                           35.9
#
# [2 rows x 358 columns]

# %% [markdown]
# ## Selección de información: por columnas o por filas
#
# **Un dataframe no es una lista**, no podemos acceder via [].
#
# La siguiente sentencia dará un error de ejecución:

# %%
df[0]

# %% [markdown]
# Si inspeccionamos i comparamos los tipos del dataframe i de las columnas...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# **¿Cómo seleccionamos los datos de una columna?**
#
# Podemos utilizar el nombre de una columna para obtener los datos de dicha columna. Al estilo de un diccionario python.
#
# Existen dos maneras:

# %%
df["Country"] #**
# Out:
# 0                   Afghanistan
# 1                       Albania
# 2                       Algeria
# 3                       Andorra
# 4                        Angola
# 5           Antigua and Barbuda
# 6                     Argentina
# 7                       Armenia
# 8                     Australia
# 9                       Austria
# 10                   Azerbaijan
# 11                      Bahamas
# 12                      Bahrain
# 13                   Bangladesh
# 14                     Barbados
# 15                      Belarus
# 16                      Belgium
# 17                       Belize
# 18                        Benin
# 19                      Bermuda
# 20                       Bhutan
# 21                      Bolivia
# 22       Bosnia and Herzegovina
# 23                     Botswana
# 24                       Brazil
# 25            Brunei Darussalam
# 26                     Bulgaria
# 27                 Burkina Faso
# 28                      Burundi
# 29                     Cambodia
#                  ...
# 172                   Swaziland
# 173                      Sweden
# 174                 Switzerland
# 175                       Syria
# 176                      Taiwan
# 177                  Tajikistan
# 178                    Tanzania
# 179                    Thailand
# 180                 Timor-Leste
# 181                        Togo
# 182                       Tonga
# 183         Trinidad and Tobago
# 184                     Tunisia
# 185                      Turkey
# 186                Turkmenistan
# 187                      Tuvalu
# 188                      Uganda
# 189                     Ukraine
# 190        United Arab Emirates
# 191              United Kingdom
# 192    United States of America
# 193                     Uruguay
# 194                  Uzbekistan
# 195                     Vanuatu
# 196                   Venezuela
# 197                     Vietnam
# 198          West Bank and Gaza
# 199                       Yemen
# 200                      Zambia
# 201                    Zimbabwe
# Name: Country, Length: 202, dtype: object

# %%
df.Country #**
# Out:
# 0                   Afghanistan
# 1                       Albania
# 2                       Algeria
# 3                       Andorra
# 4                        Angola
# 5           Antigua and Barbuda
# 6                     Argentina
# 7                       Armenia
# 8                     Australia
# 9                       Austria
# 10                   Azerbaijan
# 11                      Bahamas
# 12                      Bahrain
# 13                   Bangladesh
# 14                     Barbados
# 15                      Belarus
# 16                      Belgium
# 17                       Belize
# 18                        Benin
# 19                      Bermuda
# 20                       Bhutan
# 21                      Bolivia
# 22       Bosnia and Herzegovina
# 23                     Botswana
# 24                       Brazil
# 25            Brunei Darussalam
# 26                     Bulgaria
# 27                 Burkina Faso
# 28                      Burundi
# 29                     Cambodia
#                  ...
# 172                   Swaziland
# 173                      Sweden
# 174                 Switzerland
# 175                       Syria
# 176                      Taiwan
# 177                  Tajikistan
# 178                    Tanzania
# 179                    Thailand
# 180                 Timor-Leste
# 181                        Togo
# 182                       Tonga
# 183         Trinidad and Tobago
# 184                     Tunisia
# 185                      Turkey
# 186                Turkmenistan
# 187                      Tuvalu
# 188                      Uganda
# 189                     Ukraine
# 190        United Arab Emirates
# 191              United Kingdom
# 192    United States of America
# 193                     Uruguay
# 194                  Uzbekistan
# 195                     Vanuatu
# 196                   Venezuela
# 197                     Vietnam
# 198          West Bank and Gaza
# 199                       Yemen
# 200                      Zambia
# 201                    Zimbabwe
# Name: Country, Length: 202, dtype: object

# %% [markdown]
# **¿Qué es una columna?**

# %%
type(df.Country)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Las series són la otra estructura básica de Pandas. Las filas i las columnas se estructuran en Series, se pueden ver cómo un tipo de lista.

# %% [markdown]
# **¿Qué podemos hacer con los datos de una columna?**
#
# Con una sola línea de código podemos generar la siguiente información:

# %%
print("Valor medio de %s = %f " %(df.columns[3], df[df.columns[3]].mean()))
# Out:
# Valor medio de Adolescent fertility rate (%) = 59.457627

# %%
print(df.columns[3]) # nombre columna
# Out:
# Adolescent fertility rate (%)

# %%
print(df[df.columns[3]]) # Serie de los datos de la columna
# Out:
# 0      151.0
# 1       27.0
# 2        6.0
# 3        NaN
# 4      146.0
# 5        NaN
# 6       62.0
# 7       30.0
# 8       16.0
# 9       14.0
# 10      31.0
# 11      46.0
# 12      14.0
# 13     135.0
# 14      51.0
# 15      22.0
# 16       5.0
# 17      90.0
# 18     108.0
# 19       NaN
# 20      62.0
# 21      97.0
# 22      25.0
# 23      51.0
# 24      71.0
# 25      31.0
# 26      40.0
# 27     131.0
# 28      30.0
# 29      52.0
#        ...
# 172     73.0
# 173      7.0
# 174      5.0
# 175     58.0
# 176      NaN
# 177     57.0
# 178    139.0
# 179     70.0
# 180     49.0
# 181     89.0
# 182     17.0
# 183     35.0
# 184      8.0
# 185     51.0
# 186     29.0
# 187      NaN
# 188    159.0
# 189     29.0
# 190     37.0
# 191     27.0
# 192     43.0
# 193     64.0
# 194     40.0
# 195     92.0
# 196     81.0
# 197     25.0
# 198      NaN
# 199     83.0
# 200    161.0
# 201    101.0
# Name: Adolescent fertility rate (%), Length: 202, dtype: float64

# %% [markdown]
# ###### ¿Cómo consultarias la serie de la columna "Total_reserves"?

# %% [markdown]
# #### Sintetización de información
# Sobre las series se puede sintetizar información

# %%
fertilidad = df[df.columns[3]]
print("Minimo %f " %fertilidad.min())
print("Max %f " %fertilidad.max())
print("Mean %f " %fertilidad.mean())
print("Descripción de la serie:\n%s " %fertilidad.describe())
# Out:
# Minimo 0.000000
# Max 199.000000
# Mean 59.457627
# Descripción de la serie:
# count    177.000000
# mean      59.457627
# std       49.105286
# min        0.000000
# 25%       19.000000
# 50%       46.000000
# 75%       91.000000
# max      199.000000
# Name: Adolescent fertility rate (%), dtype: float64

# %% [markdown]
# ## Tabla con las funciones descriptivas
# <img src="img/pandas/sintetizacion.png">

# %% [markdown]
# **Una primera aproximación a la visualización**
#
# Veremos como visualizar series y dataframes en próximas secciones.

# %%
fertilidad.plot()

# %% [markdown]
# **La selección puede ser muy eficaz para encontrar elementos que cumplan ciertos criterios.**
#
# Dentro de cada 'selección' se pueden aplicar condiciones. Veamos un ejemplo...

# %% [markdown]
# #### ¿Qué pais tiene la mayor emisión de CO2 ?

# %%
co2 = df["Total_CO2_emissions"]
print(co2.max())
# Out:
# 5776431.5

# %%
row = df[df["Total_CO2_emissions"]==co2.max()]  # Esto es una condición dentro de la selección

# %% [markdown]
# Indexación con una lista de valores booleanos:

# %%
df["Total_CO2_emissions"]==co2.max()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 172    False
# 173    False
# 174    False
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191    False
# 192     True
# 193    False
# 194    False
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# 200    False
# 201    False
# Name: Total_CO2_emissions, Length: 202, dtype: bool

# %% [markdown]
# La variable row contiene la fila con el valor máximo en la columna "Total_CO2_emissions".

# %%
print(row["Total_CO2_emissions"])
# Out:
# 192    5776431.5
# Name: Total_CO2_emissions, dtype: float64

# %%
print(row["Country"])
# Out:
# 192    United States of America
# Name: Country, dtype: object

# %%
#Los valores del objeto son una lista
row["Country"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-44cef056d1d7> in <module>
#       1 #Los valores del objeto son una lista
# ----> 2 row["Country"]
#
# NameError: name 'row' is not defined

# %%
row["Country"].values
# Out:
# array(['United States of America'], dtype=object)

# %%
print(row["Country"].values[0])
# Out:
# United States of America

# %%
row
# Out:
#                       Country  CountryID  Continent  \
# 192  United States of America        193          4
#
#      Adolescent fertility rate (%)  Adult literacy rate (%)  \
# 192                           43.0                      NaN
#
#      Gross national income per capita (PPP international $)  \
# 192                                            44070.0
#
#      Net primary school enrolment ratio female (%)  \
# 192                                           93.0
#
#      Net primary school enrolment ratio male (%)  \
# 192                                         91.0
#
#      Population (in thousands) total  Population annual growth rate (%)  ...  \
# 192                         302841.0                                1.0  ...
#
#      Total_CO2_emissions  Total_income  Total_reserves  \
# 192            5776431.5  1.100000e+13             NaN
#
#      Trade_balance_goods_and_services  Under_five_mortality_from_CME  \
# 192                     -7.140000e+11                            8.0
#
#      Under_five_mortality_from_IHME  Under_five_mortality_rate  \
# 192                             7.1                        8.0
#
#      Urban_population  Urban_population_growth  Urban_population_pct_of_total
# 192       240000000.0                     1.39                           80.8
#
# [1 rows x 358 columns]

# %% [markdown]
# **Accediendo, mediante filas**

# %%
# No es una lista!!
df[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-fcdd6ee34c57> in <module>
#       1 # No es una lista!!
# ----> 2 df[0]
#
# NameError: name 'df' is not defined

# %% [markdown]
# **Iterar sobre los indices de las filas.**
#
# El siguiente atributo devuelve un iterador sobre las filas del DataFrame.

# %%
df.index
# Out:
# RangeIndex(start=0, stop=202, step=1)

# %%
for i in pd.RangeIndex(0,20,step=4):
    print(i)
# Out:
# 0
# 4
# 8
# 12
# 16

# %%
for i in np.arange(0,20,4):
    print(i)
# Out:
# 0
# 4
# 8
# 12
# 16

# %% [markdown]
# **OK, pero ¿cómo podemos acceder mediante un INDEX a una FILA?**
#
# Consultamos una fila concreta cómo se muestra a continuación. En este caso la cuarta.
#
# Atributo **loc** de los dataframes.

# %%
print(df.loc[4])
# Out:
# Country                                                                                 Angola
# CountryID                                                                                    5
# Continent                                                                                    3
# Adolescent fertility rate (%)                                                              146
# Adult literacy rate (%)                                                                   67.4
# Gross national income per capita (PPP international $)                                    3890
# Net primary school enrolment ratio female (%)                                               49
# Net primary school enrolment ratio male (%)                                                 51
# Population (in thousands) total                                                          16557
# Population annual growth rate (%)                                                          2.8
# Population in urban areas (%)                                                               54
# Population living below the poverty line (% living on &lt; US$1 per day)                   NaN
# Population median age (years)                                                               17
# Population proportion over 60 (%)                                                            4
# Population proportion under 15 (%)                                                          46
# Registration coverage of births (%)                                                         29
# Total fertility rate (per woman)                                                           6.5
# Antenatal care coverage - at least four visits (%)                                         NaN
# Antiretroviral therapy coverage among HIV-infected pregt women for PMTCT (%)                14
# Antiretroviral therapy coverage among people with advanced HIV infections (%)               16
# Births attended by skilled health personnel (%)                                             45
# Births by caesarean section (%)                                                            NaN
# Children aged 6-59 months who received vitamin A supplementation (%)                       NaN
# Children aged &lt;5 years sleeping under insecticide-treated nets (%)                      NaN
# Children aged &lt;5 years who received any antimalarial treatment for fever (%)            NaN
# Children aged &lt;5 years with ARI symptoms taken to facility (%)                          NaN
# Children aged &lt;5 years with diarrhoea receiving ORT (%)                                 NaN
# Contraceptive prevalence (%)                                                               6.2
# Neonates protected at birth against neonatal tetanus (PAB) (%)                              81
# One-year-olds immunized with MCV                                                            88
#                                                                                       ...
# Prostate_cancer_new_cases_per_100_000_men                                                 12.7
# Prostate_cancer_number_of_male_deaths                                                      285
# Prostate_cancer_number_of_new_male_cases                                                   327
# Pump_price_for_gasoline                                                                    0.5
# Ratio_of_girls_to_boys_in_primary_and_secondary_education                                85.18
# Ratio_of_young_literate_females_to_males                                                 75.44
# Roads_paved                                                                               10.4
# SO2_emissions_per_person                                                                  4.75
# Services_contribution_to_economy                                                         19.75
# Stomach_cancer_deaths_per_100_000_men                                                     13.3
# Stomach_cancer_deaths_per_100_000_women                                                    9.1
# Stomach_cancer_new_cases_per_100_000_men                                                  14.1
# Stomach_cancer_new_cases_per_100_000_women                                                 9.7
# Stomach_cancer_number_of_female_deaths                                                     323
# Stomach_cancer_number_of_male_deaths                                                       429
# Stomach_cancer_number_of_new_female_cases                                                  344
# Stomach_cancer_number_of_new_male_cases                                                    455
# Sugar_per_person                                                                         35.62
# Surface_area                                                                        1.2467e+06
# Tax_revenue                                                                                NaN
# Total_CO2_emissions                                                                    8991.46
# Total_income                                                                          1.49e+10
# Total_reserves                                                                           27.13
# Trade_balance_goods_and_services                                                      9.14e+09
# Under_five_mortality_from_CME                                                            164.1
# Under_five_mortality_from_IHME                                                           242.5
# Under_five_mortality_rate                                                                164.1
# Urban_population                                                                   8.57875e+06
# Urban_population_growth                                                                   4.14
# Urban_population_pct_of_total                                                             53.3
# Name: 4, Length: 358, dtype: object

# %% [markdown]
# Las filas són Series, cómo las columnas.

# %%
type(df.loc[4])
# Out:
# pandas.core.series.Series

# %% [markdown]
# #### Utilizando el atributo "loc" del dataframe podemos seleccionar y filtrar las filas utilizando los slicing tipicos de Python.
#
# Slicing:
# ```{python}
# sublista = lista[start:stop:step]
# ```
#
# Dónde:
# * **start** Posición de la lista original dónde empieza la sublista. Si no se indica és 0.
# * **stop**  Posición de la lista original hasta donde seleccionar. Se selecciona hasta la posición stop - 1.
# * **step**  Incremento entre cada índice de la selección, por defecto 1.

# %% [markdown]
# Si entendemos el concepto para un array...

# %%
array =[1,2,3,4,5,6,7,9,0]
print(array[0:2]) #**
print(array[3:]) #**
print(array[:3]) #**
# Out:
# [1, 2]
# [4, 5, 6, 7, 9, 0]
# [1, 2, 3]

# %% [markdown]
# ... podemos hacer las mismas operaciones con las filas de un DataFrame.

# %%
df.loc[4:10:2]
# Out:
#        Country  CountryID  Continent  Adolescent fertility rate (%)  \
# 4       Angola          5          3                          146.0
# 6    Argentina          7          5                           62.0
# 8    Australia          9          6                           16.0
# 10  Azerbaijan         11          2                           31.0
#
#     Adult literacy rate (%)  \
# 4                      67.4
# 6                      97.2
# 8                       NaN
# 10                     98.8
#
#     Gross national income per capita (PPP international $)  \
# 4                                              3890.0
# 6                                             11670.0
# 8                                             33940.0
# 10                                             5430.0
#
#     Net primary school enrolment ratio female (%)  \
# 4                                            49.0
# 6                                            98.0
# 8                                            97.0
# 10                                           83.0
#
#     Net primary school enrolment ratio male (%)  \
# 4                                          51.0
# 6                                          99.0
# 8                                          96.0
# 10                                         86.0
#
#     Population (in thousands) total  Population annual growth rate (%)  ...  \
# 4                           16557.0                                2.8  ...
# 6                           39134.0                                1.0  ...
# 8                           20530.0                                1.1  ...
# 10                           8406.0                                0.6  ...
#
#     Total_CO2_emissions  Total_income  Total_reserves  \
# 4               8991.46  1.490000e+10           27.13
# 6             152711.86  3.140000e+11           21.11
# 8             368858.53  4.680000e+11             NaN
# 10             36629.01  9.930000e+09           64.89
#
#     Trade_balance_goods_and_services  Under_five_mortality_from_CME  \
# 4                       9.140000e+09                          164.1
# 6                       1.190000e+10                           18.1
# 8                      -1.280000e+10                            5.9
# 10                      1.330000e+09                           50.0
#
#     Under_five_mortality_from_IHME  Under_five_mortality_rate  \
# 4                            242.5                      164.1
# 6                             16.7                       18.1
# 8                              5.1                        5.9
# 10                            63.7                       50.0
#
#     Urban_population  Urban_population_growth  Urban_population_pct_of_total
# 4          8578749.0                     4.14                           53.3
# 6         34900000.0                     1.17                           90.1
# 8         18000000.0                     1.54                           88.2
# 10         4321803.0                     1.26                           51.5
#
# [4 rows x 358 columns]

# %%
df.loc[200:]  #**
# Out:
#       Country  CountryID  Continent  Adolescent fertility rate (%)  \
# 200    Zambia        201          3                          161.0
# 201  Zimbabwe        202          3                          101.0
#
#      Adult literacy rate (%)  \
# 200                     68.0
# 201                     89.5
#
#      Gross national income per capita (PPP international $)  \
# 200                                             1140.0
# 201                                                NaN
#
#      Net primary school enrolment ratio female (%)  \
# 200                                           94.0
# 201                                           88.0
#
#      Net primary school enrolment ratio male (%)  \
# 200                                         90.0
# 201                                         87.0
#
#      Population (in thousands) total  Population annual growth rate (%)  ...  \
# 200                          11696.0                                1.9  ...
# 201                          13228.0                                0.8  ...
#
#      Total_CO2_emissions  Total_income  Total_reserves  \
# 200              2366.94  4.090000e+09           10.41
# 201             11457.33  5.620000e+09            3.39
#
#      Trade_balance_goods_and_services  Under_five_mortality_from_CME  \
# 200                      -447000000.0                          175.3
# 201                      -171000000.0                          106.5
#
#      Under_five_mortality_from_IHME  Under_five_mortality_rate  \
# 200                           163.8                      175.3
# 201                            67.0                      106.5
#
#      Urban_population  Urban_population_growth  Urban_population_pct_of_total
# 200         4017411.0                     1.95                           35.0
# 201         4709965.0                     1.90                           35.9
#
# [2 rows x 358 columns]

# %% [markdown]
# ## Slicing sobre matrices
#
# Ampliaremos el concepto de slicing sobre vectores y lo aplicaremos a matrices.

# %%
array =[[1,2],[2,3],[4,5],[6,7],[9,0]]
print(type(array)) #**
# Out:
# <type 'list'>

# %%
nparray = np.array(array) #**
print(type(nparray)) #**
print(nparray.shape) #**
# Out:
# <type 'numpy.ndarray'>
# (5L, 2L)

# %%
nparray
# Out:
# array([[1, 2],
#        [2, 3],
#        [4, 5],
#        [6, 7],
#        [9, 0]])

# %% [markdown]
# Cuándo aplicamos slicing soble una matriz **seleccionamos las filas**:

# %%
print(nparray[:2])
# Out:
# [[1 2]
#  [2 3]]

# %% [markdown]
# Para seleccionar un elemento debemos indicar la posición en la segunda dimensión (columna) separada por una coma (",").
#
# En el siguiente ejemplo seleccionamos el elemento de la primera fila en la segunda columna:

# %%
print(nparray[0,1])
# Out:
# 2

# %% [markdown]
# El slicing aún és más potente de lo que parece. ¡Podemos utilizarlo en todas las dimensiones!
#
# Para seleccionar todos los elementos de la segunda columna podemos hacer cómo sigue:

# %%
print(nparray[:,1])
# Out:
# [2 3 5 7 0]

# %%
# Aplicamos slicing a las filas i seleccionamos la primera columna
print(nparray[0:3,1])
# Out:
# [2 3 5]

# %% [markdown]
# ### ¿Podemos aplicar todo esto en Pandas?
#
# Si seguimos con la misma lógica, usando el atributo "loc" de los DataFrames.

# %%
df.loc[0:1]
# Out:
#        Country  CountryID  Continent  Adolescent fertility rate (%)  \
# 0  Afghanistan          1          1                          151.0
# 1      Albania          2          2                           27.0
#
#    Adult literacy rate (%)  \
# 0                     28.0
# 1                     98.7
#
#    Gross national income per capita (PPP international $)  \
# 0                                                NaN
# 1                                             6000.0
#
#    Net primary school enrolment ratio female (%)  \
# 0                                            NaN
# 1                                           93.0
#
#    Net primary school enrolment ratio male (%)  \
# 0                                          NaN
# 1                                         94.0
#
#    Population (in thousands) total  Population annual growth rate (%)  ...  \
# 0                          26088.0                                4.0  ...
# 1                           3172.0                                0.6  ...
#
#    Total_CO2_emissions  Total_income  Total_reserves  \
# 0               692.50           NaN             NaN
# 1              3499.12  4.790000e+09           78.14
#
#    Trade_balance_goods_and_services  Under_five_mortality_from_CME  \
# 0                               NaN                         257.00
# 1                     -2.040000e+09                          18.47
#
#    Under_five_mortality_from_IHME  Under_five_mortality_rate  \
# 0                           231.9                     257.00
# 1                            15.5                      18.47
#
#    Urban_population  Urban_population_growth  Urban_population_pct_of_total
# 0         5740436.0                     5.44                           22.9
# 1         1431793.9                     2.21                           45.4
#
# [2 rows x 358 columns]

# %% [markdown]
# Las columnas se deben seleccionar con una **lista** que debe contenter el nombre de las columnas deseeadas.

# %%
df.loc[0:1,["Continent"]]
# Out:
#    Continent
# 0          1
# 1          2

# %%
df.loc[0:3,["Continent","Total_CO2_emissions"]]
# Out:
#    Continent  Total_CO2_emissions
# 0          1               692.50
# 1          2              3499.12
# 2          3            137535.56
# 3          2                  NaN

# %% [markdown]
# Alternativamente, con el atributo *iloc* podemos seleccionar las columnas con su índice numérico: su posicion en la lista de columnas.

# %%
df.iloc[0]
# Out:
# Country                                                                            Afghanistan
# CountryID                                                                                    1
# Continent                                                                                    1
# Adolescent fertility rate (%)                                                              151
# Adult literacy rate (%)                                                                     28
# Gross national income per capita (PPP international $)                                     NaN
# Net primary school enrolment ratio female (%)                                              NaN
# Net primary school enrolment ratio male (%)                                                NaN
# Population (in thousands) total                                                          26088
# Population annual growth rate (%)                                                            4
# Population in urban areas (%)                                                               23
# Population living below the poverty line (% living on &lt; US$1 per day)                   NaN
# Population median age (years)                                                               16
# Population proportion over 60 (%)                                                            4
# Population proportion under 15 (%)                                                          47
# Registration coverage of births (%)                                                          6
# Total fertility rate (per woman)                                                           7.2
# Antenatal care coverage - at least four visits (%)                                         NaN
# Antiretroviral therapy coverage among HIV-infected pregt women for PMTCT (%)               NaN
# Antiretroviral therapy coverage among people with advanced HIV infections (%)              NaN
# Births attended by skilled health personnel (%)                                             14
# Births by caesarean section (%)                                                            NaN
# Children aged 6-59 months who received vitamin A supplementation (%)                       NaN
# Children aged &lt;5 years sleeping under insecticide-treated nets (%)                      NaN
# Children aged &lt;5 years who received any antimalarial treatment for fever (%)            NaN
# Children aged &lt;5 years with ARI symptoms taken to facility (%)                          NaN
# Children aged &lt;5 years with diarrhoea receiving ORT (%)                                 NaN
# Contraceptive prevalence (%)                                                              10.3
# Neonates protected at birth against neonatal tetanus (PAB) (%)                              73
# One-year-olds immunized with MCV                                                            70
#                                                                                       ...
# Prostate_cancer_new_cases_per_100_000_men                                                  4.5
# Prostate_cancer_number_of_male_deaths                                                      151
# Prostate_cancer_number_of_new_male_cases                                                   249
# Pump_price_for_gasoline                                                                   0.68
# Ratio_of_girls_to_boys_in_primary_and_secondary_education                                55.57
# Ratio_of_young_literate_females_to_males                                                  36.2
# Roads_paved                                                                              23.66
# SO2_emissions_per_person                                                                  3.14
# Services_contribution_to_economy                                                         39.42
# Stomach_cancer_deaths_per_100_000_men                                                     15.8
# Stomach_cancer_deaths_per_100_000_women                                                    8.3
# Stomach_cancer_new_cases_per_100_000_men                                                  18.5
# Stomach_cancer_new_cases_per_100_000_women                                                 9.7
# Stomach_cancer_number_of_female_deaths                                                     499
# Stomach_cancer_number_of_male_deaths                                                       936
# Stomach_cancer_number_of_new_female_cases                                                  592
# Stomach_cancer_number_of_new_male_cases                                                   1108
# Sugar_per_person                                                                           NaN
# Surface_area                                                                            652090
# Tax_revenue                                                                                NaN
# Total_CO2_emissions                                                                      692.5
# Total_income                                                                               NaN
# Total_reserves                                                                             NaN
# Trade_balance_goods_and_services                                                           NaN
# Under_five_mortality_from_CME                                                              257
# Under_five_mortality_from_IHME                                                           231.9
# Under_five_mortality_rate                                                                  257
# Urban_population                                                                   5.74044e+06
# Urban_population_growth                                                                   5.44
# Urban_population_pct_of_total                                                             22.9
# Name: 0, Length: 358, dtype: object

# %%
df.iloc[0:4, 3:7] # ídem a una matriz
# Out:
#    Adolescent fertility rate (%)  Adult literacy rate (%)  \
# 0                          151.0                     28.0
# 1                           27.0                     98.7
# 2                            6.0                     69.9
# 3                            NaN                      NaN
#
#    Gross national income per capita (PPP international $)  \
# 0                                                NaN
# 1                                             6000.0
# 2                                             5940.0
# 3                                                NaN
#
#    Net primary school enrolment ratio female (%)
# 0                                            NaN
# 1                                           93.0
# 2                                           94.0
# 3                                           83.0

# %%
df.iloc[0][0] #**
# Out:
# 'Afghanistan'

# %%
df.iloc[0][0:4]
# Out:
# Country                          Afghanistan
# CountryID                                  1
# Continent                                  1
# Adolescent fertility rate (%)            151
# Name: 0, dtype: object

# %%
df.iloc[0][0:4].values
# Out:
# array(['Afghanistan', 1, 1, 151.0], dtype=object)

# %%
df.iloc[0][0:4].values[0] #**
# Out:
# 'Afghanistan'

# %% [markdown]
# # Ejercicios

# %% [markdown]
# **1) ¿Cuál és la media de la población urbana ("Urban_population") de todos los países? ¿Su desviación típica (std)?**

# %% [markdown]
# **2) Consulta la fila del país: “Spain”**

# %% [markdown]
# **3a) ¿Qué país tiene una mayor población urbana?**

# %% [markdown]
# **3b) ¿Qué paises tienen una población urbana menor a 50000 ?**

# %% [markdown]
# **4) ¿El continente donde está situado Spain es el mismo que el de UnitedStates?**
#
# Utiliza una condición para obtener un resultado Booleano (*True* o *False*)

# %% [markdown]
# **5) ¿Cuáles son los cinco paises más contaminantes ("Total_CO2_emissions")?**
#
# Esta es mi pista para una solución elegante: http://pandas.pydata.org/pandas-docs/version/0.19.2/generated/pandas.DataFrame.sort_values.html

# %% [markdown]
# **6) Observando algunas muestras del fichero puedes establecer la relación entre el identificador del continente y su nombre?**
#
# Es decir, sabemos que Spain está en el continente Europeo y el código del continente es el 2.
#
# Existen los códigos de continentes: 1, 2, 3, 4, 5, 6, 7
#
# **Nota:** Hay dos códigos asociados a Asia.
#
# Haz las consultas pertinentes al dataframe para construir un diccionario con la siguiente estructura:

# %%
codigoContinentes = {1:"Asia",2:"Europa"} #Al menos hay 7!
print(codigoContinentes[2])
# Out:
# Europa

# %%
codigoContinentes[3] = ""
codigoContinentes[4] = ""
codigoContinentes[5] = ""
codigoContinentes[6] = ""
codigoContinentes[7] = ""

# %% [markdown]
# **7) Una vez identificado el nombre de los continentes, ¿puedes cambiar la columna de identificadores de continentes por sus respectivos nombres?**
#
# Esta es es mi pista para una solución elegante: http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.map.html

# %% [markdown]
# **8) Puedes crear un nuevo dataframe con aquellos paises que sean de Europa?**

# %%
df2 = df #Con una simple asignación ya creas una dataframe 
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **9) ¿Cuáles son los paises más contaminantes de Europa?**
#
# Propuesta A: usa el dataframe inicial

# %% [markdown]
# Propuesta B: usa el dataframe de la actividad 8

# %% [markdown]
# ### Conclusión
# **Que hemos visto en este *notebook*:**
#
#  * Carga de ficheros CSV
#  * Selección de filas y columnas de un dataframe
#  * Aplicación de criterios en la selección
